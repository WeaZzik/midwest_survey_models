# %% [markdown]
# # Explore the Midwest Survey dataset
#
# In this notebook, we will explore the **Midwest Survey** dataset from [skrub](https://skrub-data.org/).
#
# This dataset contains survey responses from people across the United States,
# asking them about their perception of the Midwest region.
#
# The goal is to predict the **Census Region** where a respondent lives,
# based on their survey answers.

# %% [markdown]
# ## Load the dataset

# %%
from skrub.datasets import fetch_midwest_survey

dataset = fetch_midwest_survey()

# X contains the features (the survey answers)
X = dataset.X
# y contains the target (the Census Region)
y = dataset.y
# Out:
# Downloading 'midwest_survey' from https://github.com/skrub-data/skrub-data-files/raw/refs/heads/main/midwest_survey.zip (attempt 1/3)

# %% [markdown]
# ## Question 1: How many examples are there in the dataset?
#
# Use the `.shape` attribute to find out the number of rows and columns.

# %%
X.shape
# Display the number of rows and columns
# Out:
# (2494, 28)

# %%
# You can also look at the first few rows of the dataset
X.head()
# Out:
#    RespondentID What_would_you_call_the_part_of_the_country_you_live_in_now  \
# 0  3.126807e+09                                           Southern
# 1  3.126791e+09                                            Midwest
# 2  3.126781e+09                                           Mid-west
# 3  3.126770e+09                                           midewest
# 4  3.126765e+09                                            Midwest
#
#   How_much_do_you_personally_identify_as_a_Midwesterner  \
# 0                                           Not much
# 1                                           Not much
# 2                                              A lot
# 3                                              A lot
# 4                                               Some
#
#   Do_you_consider_Illinois_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do_you_consider_Indiana_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do_you_consider_Iowa_state_as_part_of_the_Midwest  \
# 0                                                No
# 1                                               Yes
# 2                                                No
# 3                                               Yes
# 4                                               Yes
#
#   Do_you_consider_Kansas_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Do_you_consider_Michigan_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   Do_you_consider_Minnesota_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Do_you_consider_Missouri_state_as_part_of_the_Midwest  ...  \
# 0                                                 No     ...
# 1                                                Yes     ...
# 2                                                 No     ...
# 3                                                 No     ...
# 4                                                Yes     ...
#
#   Do_you_consider_Oklahoma_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Do_you_consider_Pennsylvania_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Do_you_consider_West_Virginia_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   Do_you_consider_Montana_state_as_part_of_the_Midwest  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Do_you_consider_Wyoming_state_as_part_of_the_Midwest Gender    Age  \
# 0                                                 No     Male  18-29
# 1                                                 No     Male  18-29
# 2                                                 No     Male  18-29
# 3                                                 No     Male  18-29
# 4                                                 No     Male  30-44
#
#     Household_Income                     Education  \
# 0  $50,000 - $99,999            High school degree
# 1       $0 - $24,999  Associate or bachelor degree
# 2  $25,000 - $49,999  Associate or bachelor degree
# 3  $50,000 - $99,999  Associate or bachelor degree
# 4          $150,000+               Graduate degree
#
#   In_what_ZIP_code_is_your_home_located
# 0                                 74070
# 1                                 44106
# 2                                 48185
# 3                                 45040
# 4                                 44054
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Question 2: What is the distribution of the target?
#
# The target variable `y` tells us the Census Region of each respondent.
# Let's see how many respondents belong to each region.

# %%
y.value_counts()
# Count how many respondents belong to each region
# Out:
# Census_Region
# East North Central    758
# West North Central    358
# Middle Atlantic       334
# South Atlantic        248
# Pacific               243
# Mountain              190
# West South Central    172
# East South Central     97
# New England            94
# Name: count, dtype: int64

# %%
y.value_counts().plot(
    kind='barh',
)
# Visualize the target distribution with a bar plot
# hint: use barh
# Out:
# <Axes: ylabel='Census_Region'>

# %% [markdown]
# Is the target balanced (roughly the same number of examples per class) or imbalanced?

# %% [markdown]
# ## Question 3: What are the features that can be used to predict the target?
#
# Let's look at the column names and their data types.

# %%
X.columns
# List all column names
# Out:
# 'Census_Region'

# %%
for e in X.columns:
    print(e,type(e))
# Show data types for each column
# Out:
# RespondentID <class 'str'>
# What_would_you_call_the_part_of_the_country_you_live_in_now <class 'str'>
# How_much_do_you_personally_identify_as_a_Midwesterner <class 'str'>
# Do_you_consider_Illinois_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Indiana_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Iowa_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Kansas_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Michigan_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Minnesota_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Missouri_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Nebraska_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_North_Dakota_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Ohio_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_South_Dakota_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Wisconsin_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Arkansas_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Colorado_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Kentucky_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Oklahoma_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Pennsylvania_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_West_Virginia_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Montana_state_as_part_of_the_Midwest <class 'str'>
# Do_you_consider_Wyoming_state_as_part_of_the_Midwest <class 'str'>
# Gender <class 'str'>
# Age <class 'str'>
# Household_Income <class 'str'>
# Education <class 'str'>
# In_what_ZIP_code_is_your_home_located <class 'str'>

# %% [markdown]
# How many features are numerical? How many are categorical (text)?

# %%
Pas de variable numérique
# Out:
# Index(['RespondentID',
#        'What_would_you_call_the_part_of_the_country_you_live_in_now',
#        'How_much_do_you_personally_identify_as_a_Midwesterner',
#        'Do_you_consider_Illinois_state_as_part_of_the_Midwest',
#        'Do_you_consider_Indiana_state_as_part_of_the_Midwest',
#        'Do_you_consider_Iowa_state_as_part_of_the_Midwest',
#        'Do_you_consider_Kansas_state_as_part_of_the_Midwest',
#        'Do_you_consider_Michigan_state_as_part_of_the_Midwest',
#        'Do_you_consider_Minnesota_state_as_part_of_the_Midwest',
#        'Do_you_consider_Missouri_state_as_part_of_the_Midwest',
#        'Do_you_consider_Nebraska_state_as_part_of_the_Midwest',
#        'Do_you_consider_North_Dakota_state_as_part_of_the_Midwest',
#        'Do_you_consider_Ohio_state_as_part_of_the_Midwest',
#        'Do_you_consider_South_Dakota_state_as_part_of_the_Midwest',
#        'Do_you_consider_Wisconsin_state_as_part_of_the_Midwest',
#        'Do_you_consider_Arkansas_state_as_part_of_the_Midwest',
#        'Do_you_consider_Colorado_state_as_part_of_the_Midwest',
#        'Do_you_consider_Kentucky_state_as_part_of_the_Midwest',
#        'Do_you_consider_Oklahoma_state_as_part_of_the_Midwest',
#        'Do_you_consider_Pennsylvania_state_as_part_of_the_Midwest',
#        'Do_you_consider_West_Virginia_state_as_part_of_the_Midwest',
#        'Do_you_consider_Montana_state_as_part_of_the_Midwest',
#        'Do_you_consider_Wyoming_state_as_part_of_the_Midwest', 'Gender', 'Age',
#        'Household_Income', 'Education',
#        'In_what_ZIP_code_is_your_home_located'],
#       dtype='str')

# %%
from skrub import TableReport
TableReport(X)
# Out:
# Processing column  28 / 28
# <TableReport: use .open() to display>

# %% [markdown]
# ## Question 4: Are there any missing values in the dataset?
#
# Missing values can cause problems for machine learning models.
# Let's check if there are any.

# %%
X.isna().sum()
# Check for NaN missing values
# Out:
# RespondentID                                                   0
# What_would_you_call_the_part_of_the_country_you_live_in_now    0
# How_much_do_you_personally_identify_as_a_Midwesterner          0
# Do_you_consider_Illinois_state_as_part_of_the_Midwest          0
# Do_you_consider_Indiana_state_as_part_of_the_Midwest           0
# Do_you_consider_Iowa_state_as_part_of_the_Midwest              0
# Do_you_consider_Kansas_state_as_part_of_the_Midwest            0
# Do_you_consider_Michigan_state_as_part_of_the_Midwest          0
# Do_you_consider_Minnesota_state_as_part_of_the_Midwest         0
# Do_you_consider_Missouri_state_as_part_of_the_Midwest          0
# Do_you_consider_Nebraska_state_as_part_of_the_Midwest          0
# Do_you_consider_North_Dakota_state_as_part_of_the_Midwest      0
# Do_you_consider_Ohio_state_as_part_of_the_Midwest              0
# Do_you_consider_South_Dakota_state_as_part_of_the_Midwest      0
# Do_you_consider_Wisconsin_state_as_part_of_the_Midwest         0
# Do_you_consider_Arkansas_state_as_part_of_the_Midwest          0
# Do_you_consider_Colorado_state_as_part_of_the_Midwest          0
# Do_you_consider_Kentucky_state_as_part_of_the_Midwest          0
# Do_you_consider_Oklahoma_state_as_part_of_the_Midwest          0
# Do_you_consider_Pennsylvania_state_as_part_of_the_Midwest      0
# Do_you_consider_West_Virginia_state_as_part_of_the_Midwest     0
# Do_you_consider_Montana_state_as_part_of_the_Midwest           0
# Do_you_consider_Wyoming_state_as_part_of_the_Midwest           0
# Gender                                                         0
# Age                                                            0
# Household_Income                                               0
# Education                                                      0
# In_what_ZIP_code_is_your_home_located                          0
# dtype: int64

# %% [markdown]
# Missing values can sometimes be encoded differently. Let's look at some columns more closely.

# %%
X["Household_Income"].unique
# Look at unique values for the Household_Income column
#X["Household_Income"].??
# Out:
# <bound method Series.unique of 0       $50,000 - $99,999
# 1            $0 - $24,999
# 2       $25,000 - $49,999
# 3       $50,000 - $99,999
# 4               $150,000+
#               ...
# 2489    $50,000 - $99,999
# 2490         $0 - $24,999
# 2491            $150,000+
# 2492    $50,000 - $99,999
# 2493            $150,000+
# Name: Household_Income, Length: 2494, dtype: str>

# %%
X["Education"].unique
# Look at unique values for the Education column

# 2491 > "Some college" seems weird..
# Out:
# <bound method Series.unique of 0                 High school degree
# 1       Associate or bachelor degree
# 2       Associate or bachelor degree
# 3       Associate or bachelor degree
# 4                    Graduate degree
#                     ...
# 2489                 Graduate degree
# 2490                 Graduate degree
# 2491                    Some college
# 2492                 Graduate degree
# 2493                 Graduate degree
# Name: Education, Length: 2494, dtype: str>

# %% [markdown]
# Do you see a special value that could represent missing data?

# %% [markdown]
# ## Question 5: What is the most common answer to "How much do you personally identify as a Midwesterner"?
#
# Let's explore this important feature.

# %%
# TODO: display the value counts for the column
# "How_much_do_you_personally_identify_as_a_Midwesterner"
X["How_much_do_you_personally_identify_as_a_Midwesterner"].value_counts()
# Out:
# How_much_do_you_personally_identify_as_a_Midwesterner
# Not at all    965
# A lot         697
# Some          528
# Not much      304
# Name: count, dtype: int64

# %%
# TODO: make a bar plot of the results
X["How_much_do_you_personally_identify_as_a_Midwesterner"].value_counts().plot(
    kind='barh',
)
# Out:
# <Axes: ylabel='How_much_do_you_personally_identify_as_a_Midwesterner'>

# %% [markdown]
# ## Bonus: Explore another feature
#
# Pick another column and explore its distribution.
# For example: `Gender`, `Age`, or one of the
# "Do you consider X state as part of the Midwest" columns.

# %%
# TODO: explore a column of your choice

X["Age"].value_counts().plot(
    kind='barh',
)
# Out:
# <Axes: ylabel='Age'>
